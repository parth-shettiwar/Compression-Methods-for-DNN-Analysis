# %%
#Importing Drive
import sys
runningOnColab = 'google.colab' in sys.modules
if runningOnColab:
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd '/content/drive/Shareddrives/CS259/KD/knowledge-distillation-pytorch'
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/CS259/KD/knowledge-distillation-pytorch

# %%
# !pip install torchnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchnet
#   Downloading torchnet-0.0.4.tar.gz (23 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchnet) (1.11.0+cu113)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchnet) (1.15.0)
# Collecting visdom
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
#      |████████████████████████████████| 676 kB 19.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchnet) (4.2.0)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (5.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (23.0.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.5 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet) (7.1.2)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet) (2022.5.18.1)
# Building wheels for collected packages: torchnet, visdom, torchfile
#   Building wheel for torchnet (setup.py) ... done
#   Created wheel for torchnet: filename=torchnet-0.0.4-py3-none-any.whl size=29742 sha256=a836a0a89b3ae98a367891577ae0e888f75e1853774b4e1619c1a82b73bf7af4
#   Stored in directory: /root/.cache/pip/wheels/93/17/b3/86db1d93e9dae198813aa79831b403e4844d67986cf93894b5
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=bb40db605a18bfecca3832df33e61d933dd4d94a455928962eb122ce753a2d89
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=d79e0c800b42b8894e94e233d346ef18611c459604d0570cccfc562f63f5e791
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built torchnet visdom torchfile
# Installing collected packages: jsonpointer, websocket-client, torchfile, jsonpatch, visdom, torchnet
# Successfully installed jsonpatch-1.32 jsonpointer-2.3 torchfile-0.1.0 torchnet-0.0.4 visdom-0.1.8.9 websocket-client-1.3.2

# %% [markdown]
# # Reduce the filter size

# %%
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:16<00:00, 23.10it/s, loss=0.620]
# - Train metrics: accuracy: 0.418 ; loss: 0.723
# inference latency =  0.16160345077514648
# - Eval metrics : accuracy: 0.633 ; loss: 0.000
# inference latency =  0.5829341411590576
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 2/20
# 100% 391/391 [00:17<00:00, 22.83it/s, loss=0.483]
# - Train metrics: accuracy: 0.617 ; loss: 0.492
# inference latency =  0.1698904037475586
# - Eval metrics : accuracy: 0.685 ; loss: 0.000
# inference latency =  0.5547707080841064
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 3/20
# 100% 391/391 [00:17<00:00, 22.77it/s, loss=0.433]
# - Train metrics: accuracy: 0.711 ; loss: 0.415
# inference latency =  0.19506406784057617
# - Eval metrics : accuracy: 0.716 ; loss: 0.000
# inference latency =  0.5391228199005127
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 22.81it/s, loss=0.402]
# - Train metrics: accuracy: 0.709 ; loss: 0.399
# inference latency =  0.13631153106689453
# - Eval metrics : accuracy: 0.723 ; loss: 0.000
# inference latency =  0.5653629302978516
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 22.93it/s, loss=0.379]
# - Train metrics: accuracy: 0.688 ; loss: 0.404
# inference latency =  0.1702404022216797
# - Eval metrics : accuracy: 0.735 ; loss: 0.000
# inference latency =  0.5516231060028076
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 6/20
# 100% 391/391 [00:17<00:00, 22.90it/s, loss=0.362]
# - Train metrics: accuracy: 0.742 ; loss: 0.349
# inference latency =  0.16576766967773438
# - Eval metrics : accuracy: 0.765 ; loss: 0.000
# inference latency =  0.5252039432525635
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 7/20
# 100% 391/391 [00:17<00:00, 22.67it/s, loss=0.352]
# - Train metrics: accuracy: 0.748 ; loss: 0.347
# inference latency =  0.14957070350646973
# - Eval metrics : accuracy: 0.768 ; loss: 0.000
# inference latency =  0.48851561546325684
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 8/20
# 100% 391/391 [00:18<00:00, 21.08it/s, loss=0.343]
# - Train metrics: accuracy: 0.732 ; loss: 0.372
# inference latency =  0.16709399223327637
# - Eval metrics : accuracy: 0.769 ; loss: 0.000
# inference latency =  0.5681228637695312
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 22.80it/s, loss=0.333]
# - Train metrics: accuracy: 0.781 ; loss: 0.308
# inference latency =  0.14283490180969238
# - Eval metrics : accuracy: 0.784 ; loss: 0.000
# inference latency =  0.5334570407867432
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 22.80it/s, loss=0.325]
# - Train metrics: accuracy: 0.756 ; loss: 0.338
# inference latency =  0.15824556350708008
# - Eval metrics : accuracy: 0.785 ; loss: 0.000
# inference latency =  0.5310442447662354
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 22.76it/s, loss=0.318]
# - Train metrics: accuracy: 0.740 ; loss: 0.337
# inference latency =  0.148834228515625
# - Eval metrics : accuracy: 0.787 ; loss: 0.000
# inference latency =  0.5422601699829102
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 22.90it/s, loss=0.314]
# - Train metrics: accuracy: 0.791 ; loss: 0.317
# inference latency =  0.16976428031921387
# - Eval metrics : accuracy: 0.791 ; loss: 0.000
# inference latency =  0.5467679500579834
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 13/20
# 100% 391/391 [00:16<00:00, 23.01it/s, loss=0.306]
# - Train metrics: accuracy: 0.770 ; loss: 0.323
# inference latency =  0.18235087394714355
# - Eval metrics : accuracy: 0.790 ; loss: 0.000
# inference latency =  0.568758487701416
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 14/20
# 100% 391/391 [00:17<00:00, 22.70it/s, loss=0.300]
# - Train metrics: accuracy: 0.795 ; loss: 0.294
# inference latency =  0.16730356216430664
# - Eval metrics : accuracy: 0.799 ; loss: 0.000
# inference latency =  0.5285227298736572
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 15/20
# 100% 391/391 [00:17<00:00, 22.95it/s, loss=0.297]
# - Train metrics: accuracy: 0.779 ; loss: 0.303
# inference latency =  0.1833953857421875
# - Eval metrics : accuracy: 0.805 ; loss: 0.000
# inference latency =  0.5409083366394043
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 16/20
# 100% 391/391 [00:17<00:00, 22.99it/s, loss=0.294]
# - Train metrics: accuracy: 0.824 ; loss: 0.285
# inference latency =  0.1708540916442871
# - Eval metrics : accuracy: 0.799 ; loss: 0.000
# inference latency =  0.5654098987579346
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 22.80it/s, loss=0.290]
# - Train metrics: accuracy: 0.789 ; loss: 0.299
# inference latency =  0.1807558536529541
# - Eval metrics : accuracy: 0.809 ; loss: 0.000
# inference latency =  0.5640015602111816
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 22.60it/s, loss=0.285]
# - Train metrics: accuracy: 0.803 ; loss: 0.289
# inference latency =  0.14118695259094238
# - Eval metrics : accuracy: 0.804 ; loss: 0.000
# inference latency =  0.5308780670166016
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 19/20
# 100% 391/391 [00:18<00:00, 21.12it/s, loss=0.282]
# - Train metrics: accuracy: 0.816 ; loss: 0.265
# inference latency =  0.16532611846923828
# - Eval metrics : accuracy: 0.800 ; loss: 0.000
# inference latency =  0.5142779350280762
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 22.93it/s, loss=0.280]
# - Train metrics: accuracy: 0.803 ; loss: 0.296
# inference latency =  0.1792616844177246
# - Eval metrics : accuracy: 0.803 ; loss: 0.000
# inference latency =  0.5098989009857178
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  376330

# %% [markdown]
# # Lesser Channels

# %%
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:17<00:00, 22.57it/s, loss=0.637]
# - Train metrics: accuracy: 0.434 ; loss: 0.725
# inference latency =  0.17042255401611328
# - Eval metrics : accuracy: 0.653 ; loss: 0.000
# inference latency =  0.5300588607788086
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 2/20
# 100% 391/391 [00:17<00:00, 22.15it/s, loss=0.477]
# - Train metrics: accuracy: 0.697 ; loss: 0.462
# inference latency =  0.16841816902160645
# - Eval metrics : accuracy: 0.699 ; loss: 0.000
# inference latency =  0.5987231731414795
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 3/20
# 100% 391/391 [00:17<00:00, 22.45it/s, loss=0.420]
# - Train metrics: accuracy: 0.695 ; loss: 0.422
# inference latency =  0.1482377052307129
# - Eval metrics : accuracy: 0.713 ; loss: 0.000
# inference latency =  0.5302133560180664
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 22.61it/s, loss=0.389]
# - Train metrics: accuracy: 0.727 ; loss: 0.412
# inference latency =  0.17664718627929688
# - Eval metrics : accuracy: 0.751 ; loss: 0.000
# inference latency =  0.5580155849456787
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 22.69it/s, loss=0.364]
# - Train metrics: accuracy: 0.787 ; loss: 0.353
# inference latency =  0.1532895565032959
# - Eval metrics : accuracy: 0.769 ; loss: 0.000
# inference latency =  0.5626780986785889
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 6/20
# 100% 391/391 [00:18<00:00, 20.81it/s, loss=0.345]
# - Train metrics: accuracy: 0.773 ; loss: 0.321
# inference latency =  0.15082979202270508
# - Eval metrics : accuracy: 0.783 ; loss: 0.000
# inference latency =  0.569206714630127
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 7/20
# 100% 391/391 [00:17<00:00, 22.24it/s, loss=0.330]
# - Train metrics: accuracy: 0.783 ; loss: 0.331
# inference latency =  0.1862163543701172
# - Eval metrics : accuracy: 0.789 ; loss: 0.000
# inference latency =  0.5562162399291992
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 8/20
# 100% 391/391 [00:17<00:00, 22.46it/s, loss=0.319]
# - Train metrics: accuracy: 0.742 ; loss: 0.335
# inference latency =  0.1587231159210205
# - Eval metrics : accuracy: 0.795 ; loss: 0.000
# inference latency =  0.6465222835540771
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 22.57it/s, loss=0.308]
# - Train metrics: accuracy: 0.803 ; loss: 0.290
# inference latency =  0.1539018154144287
# - Eval metrics : accuracy: 0.810 ; loss: 0.000
# inference latency =  0.5100562572479248
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 22.53it/s, loss=0.301]
# - Train metrics: accuracy: 0.807 ; loss: 0.304
# inference latency =  0.1739046573638916
# - Eval metrics : accuracy: 0.805 ; loss: 0.000
# inference latency =  0.5016241073608398
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 22.65it/s, loss=0.292]
# - Train metrics: accuracy: 0.822 ; loss: 0.284
# inference latency =  0.17966294288635254
# - Eval metrics : accuracy: 0.820 ; loss: 0.000
# inference latency =  0.5539264678955078
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 22.74it/s, loss=0.287]
# - Train metrics: accuracy: 0.828 ; loss: 0.275
# inference latency =  0.17497539520263672
# - Eval metrics : accuracy: 0.820 ; loss: 0.000
# inference latency =  0.5990273952484131
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 13/20
# 100% 391/391 [00:17<00:00, 22.47it/s, loss=0.281]
# - Train metrics: accuracy: 0.816 ; loss: 0.283
# inference latency =  0.19098448753356934
# - Eval metrics : accuracy: 0.825 ; loss: 0.000
# inference latency =  0.531815767288208
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 14/20
# 100% 391/391 [00:17<00:00, 22.76it/s, loss=0.277]
# - Train metrics: accuracy: 0.814 ; loss: 0.274
# inference latency =  0.1720573902130127
# - Eval metrics : accuracy: 0.824 ; loss: 0.000
# inference latency =  0.5518698692321777
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 15/20
# 100% 391/391 [00:17<00:00, 22.62it/s, loss=0.270]
# - Train metrics: accuracy: 0.838 ; loss: 0.268
# inference latency =  0.1569077968597412
# - Eval metrics : accuracy: 0.827 ; loss: 0.000
# inference latency =  0.5974187850952148
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 16/20
# 100% 391/391 [00:18<00:00, 21.45it/s, loss=0.268]
# - Train metrics: accuracy: 0.854 ; loss: 0.243
# inference latency =  0.15728235244750977
# - Eval metrics : accuracy: 0.837 ; loss: 0.000
# inference latency =  0.5282077789306641
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 22.78it/s, loss=0.263]
# - Train metrics: accuracy: 0.855 ; loss: 0.244
# inference latency =  0.158036470413208
# - Eval metrics : accuracy: 0.831 ; loss: 0.000
# inference latency =  0.5885124206542969
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 22.54it/s, loss=0.260]
# - Train metrics: accuracy: 0.826 ; loss: 0.271
# inference latency =  0.16423511505126953
# - Eval metrics : accuracy: 0.834 ; loss: 0.000
# inference latency =  0.5702202320098877
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 19/20
# 100% 391/391 [00:17<00:00, 22.72it/s, loss=0.256]
# - Train metrics: accuracy: 0.869 ; loss: 0.242
# inference latency =  0.16957306861877441
# - Eval metrics : accuracy: 0.839 ; loss: 0.000
# inference latency =  0.5275166034698486
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 22.52it/s, loss=0.252]
# - Train metrics: accuracy: 0.824 ; loss: 0.263
# inference latency =  0.16884160041809082
# - Eval metrics : accuracy: 0.832 ; loss: 0.000
# inference latency =  0.5772171020507812
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354

# %% [markdown]
# # Less FC

# %%
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:17<00:00, 22.83it/s, loss=0.584]
# - Train metrics: accuracy: 0.449 ; loss: 0.707
# inference latency =  0.13407158851623535
# - Eval metrics : accuracy: 0.681 ; loss: 0.000
# inference latency =  0.5580635070800781
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 2/20
# 100% 391/391 [00:17<00:00, 22.78it/s, loss=0.420]
# - Train metrics: accuracy: 0.732 ; loss: 0.425
# inference latency =  0.14510107040405273
# - Eval metrics : accuracy: 0.727 ; loss: 0.000
# inference latency =  0.5869731903076172
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 3/20
# 100% 391/391 [00:17<00:00, 22.79it/s, loss=0.362]
# - Train metrics: accuracy: 0.732 ; loss: 0.372
# inference latency =  0.1332542896270752
# - Eval metrics : accuracy: 0.712 ; loss: 0.000
# inference latency =  0.5397636890411377
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 22.45it/s, loss=0.327]
# - Train metrics: accuracy: 0.754 ; loss: 0.330
# inference latency =  0.15697813034057617
# - Eval metrics : accuracy: 0.790 ; loss: 0.000
# inference latency =  0.5413587093353271
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 22.47it/s, loss=0.301]
# - Train metrics: accuracy: 0.771 ; loss: 0.296
# inference latency =  0.15651845932006836
# - Eval metrics : accuracy: 0.784 ; loss: 0.000
# inference latency =  0.5453722476959229
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 6/20
# 100% 391/391 [00:17<00:00, 22.91it/s, loss=0.282]
# - Train metrics: accuracy: 0.807 ; loss: 0.286
# inference latency =  0.15366220474243164
# - Eval metrics : accuracy: 0.801 ; loss: 0.000
# inference latency =  0.5256109237670898
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 7/20
# 100% 391/391 [00:18<00:00, 20.96it/s, loss=0.268]
# - Train metrics: accuracy: 0.816 ; loss: 0.265
# inference latency =  0.1554431915283203
# - Eval metrics : accuracy: 0.799 ; loss: 0.000
# inference latency =  0.5490968227386475
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 8/20
# 100% 391/391 [00:17<00:00, 22.42it/s, loss=0.257]
# - Train metrics: accuracy: 0.814 ; loss: 0.269
# inference latency =  0.16182255744934082
# - Eval metrics : accuracy: 0.817 ; loss: 0.000
# inference latency =  0.5873003005981445
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 22.89it/s, loss=0.245]
# - Train metrics: accuracy: 0.832 ; loss: 0.242
# inference latency =  0.13345861434936523
# - Eval metrics : accuracy: 0.825 ; loss: 0.000
# inference latency =  0.5282588005065918
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 22.84it/s, loss=0.236]
# - Train metrics: accuracy: 0.857 ; loss: 0.228
# inference latency =  0.13589954376220703
# - Eval metrics : accuracy: 0.826 ; loss: 0.000
# inference latency =  0.5874829292297363
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 22.76it/s, loss=0.229]
# - Train metrics: accuracy: 0.854 ; loss: 0.231
# inference latency =  0.13267755508422852
# - Eval metrics : accuracy: 0.825 ; loss: 0.000
# inference latency =  0.5704095363616943
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 22.72it/s, loss=0.220]
# - Train metrics: accuracy: 0.873 ; loss: 0.214
# inference latency =  0.13313961029052734
# - Eval metrics : accuracy: 0.816 ; loss: 0.000
# inference latency =  0.5260975360870361
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 13/20
# 100% 391/391 [00:17<00:00, 22.75it/s, loss=0.215]
# - Train metrics: accuracy: 0.871 ; loss: 0.205
# inference latency =  0.1318962574005127
# - Eval metrics : accuracy: 0.840 ; loss: 0.000
# inference latency =  0.5742242336273193
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 14/20
# 100% 391/391 [00:17<00:00, 22.62it/s, loss=0.210]
# - Train metrics: accuracy: 0.848 ; loss: 0.217
# inference latency =  0.13434076309204102
# - Eval metrics : accuracy: 0.841 ; loss: 0.000
# inference latency =  0.5103344917297363
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 15/20
# 100% 391/391 [00:17<00:00, 22.54it/s, loss=0.205]
# - Train metrics: accuracy: 0.885 ; loss: 0.193
# inference latency =  0.17950081825256348
# - Eval metrics : accuracy: 0.842 ; loss: 0.000
# inference latency =  0.5646171569824219
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 16/20
# 100% 391/391 [00:17<00:00, 22.69it/s, loss=0.199]
# - Train metrics: accuracy: 0.857 ; loss: 0.206
# inference latency =  0.14309477806091309
# - Eval metrics : accuracy: 0.848 ; loss: 0.000
# inference latency =  0.5575947761535645
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 22.71it/s, loss=0.195]
# - Train metrics: accuracy: 0.881 ; loss: 0.187
# inference latency =  0.16234326362609863
# - Eval metrics : accuracy: 0.851 ; loss: 0.000
# inference latency =  0.6010870933532715
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 22.40it/s, loss=0.191]
# - Train metrics: accuracy: 0.900 ; loss: 0.190
# inference latency =  0.13260793685913086
# - Eval metrics : accuracy: 0.845 ; loss: 0.000
# inference latency =  0.8154113292694092
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 19/20
# 100% 391/391 [00:17<00:00, 22.54it/s, loss=0.188]
# - Train metrics: accuracy: 0.873 ; loss: 0.184
# inference latency =  0.14113068580627441
# - Eval metrics : accuracy: 0.849 ; loss: 0.000
# inference latency =  0.5501666069030762
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 22.86it/s, loss=0.183]
# - Train metrics: accuracy: 0.869 ; loss: 0.180
# inference latency =  0.14762020111083984
# - Eval metrics : accuracy: 0.852 ; loss: 0.000
# inference latency =  0.49613189697265625
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  399626

# %% [markdown]
# # Less Channels + Remove FC

# %%
# Combined
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:17<00:00, 22.83it/s, loss=0.589]
# - Train metrics: accuracy: 0.438 ; loss: 0.698
# inference latency =  0.15952658653259277
# - Eval metrics : accuracy: 0.655 ; loss: 0.000
# inference latency =  0.6073715686798096
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 2/20
# 100% 391/391 [00:17<00:00, 22.60it/s, loss=0.437]
# - Train metrics: accuracy: 0.652 ; loss: 0.461
# inference latency =  0.14223289489746094
# - Eval metrics : accuracy: 0.667 ; loss: 0.000
# inference latency =  0.6075088977813721
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 3/20
# 100% 391/391 [00:17<00:00, 22.70it/s, loss=0.377]
# - Train metrics: accuracy: 0.693 ; loss: 0.423
# inference latency =  0.12713408470153809
# - Eval metrics : accuracy: 0.739 ; loss: 0.000
# inference latency =  0.5709309577941895
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 22.13it/s, loss=0.347]
# - Train metrics: accuracy: 0.727 ; loss: 0.372
# inference latency =  0.19505953788757324
# - Eval metrics : accuracy: 0.767 ; loss: 0.000
# inference latency =  0.5577092170715332
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 22.59it/s, loss=0.321]
# - Train metrics: accuracy: 0.754 ; loss: 0.333
# inference latency =  0.13413405418395996
# - Eval metrics : accuracy: 0.781 ; loss: 0.000
# inference latency =  0.6050105094909668
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 6/20
# 100% 391/391 [00:17<00:00, 22.60it/s, loss=0.304]
# - Train metrics: accuracy: 0.785 ; loss: 0.311
# inference latency =  0.13455414772033691
# - Eval metrics : accuracy: 0.774 ; loss: 0.000
# inference latency =  0.5464596748352051
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 7/20
# 100% 391/391 [00:17<00:00, 22.64it/s, loss=0.291]
# - Train metrics: accuracy: 0.750 ; loss: 0.313
# inference latency =  0.12685298919677734
# - Eval metrics : accuracy: 0.778 ; loss: 0.000
# inference latency =  0.5670528411865234
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 8/20
# 100% 391/391 [00:17<00:00, 22.63it/s, loss=0.277]
# - Train metrics: accuracy: 0.809 ; loss: 0.278
# inference latency =  0.15161609649658203
# - Eval metrics : accuracy: 0.810 ; loss: 0.000
# inference latency =  0.5447430610656738
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 22.38it/s, loss=0.265]
# - Train metrics: accuracy: 0.793 ; loss: 0.280
# inference latency =  0.1477222442626953
# - Eval metrics : accuracy: 0.807 ; loss: 0.000
# inference latency =  0.579979419708252
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 22.61it/s, loss=0.257]
# - Train metrics: accuracy: 0.832 ; loss: 0.245
# inference latency =  0.1389143466949463
# - Eval metrics : accuracy: 0.812 ; loss: 0.000
# inference latency =  0.5633926391601562
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 22.72it/s, loss=0.248]
# - Train metrics: accuracy: 0.848 ; loss: 0.244
# inference latency =  0.13094592094421387
# - Eval metrics : accuracy: 0.811 ; loss: 0.000
# inference latency =  0.5262482166290283
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 22.63it/s, loss=0.244]
# - Train metrics: accuracy: 0.842 ; loss: 0.239
# inference latency =  0.16985845565795898
# - Eval metrics : accuracy: 0.812 ; loss: 0.000
# inference latency =  0.6108741760253906
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 13/20
# 100% 391/391 [00:17<00:00, 22.63it/s, loss=0.236]
# - Train metrics: accuracy: 0.818 ; loss: 0.253
# inference latency =  0.12125515937805176
# - Eval metrics : accuracy: 0.823 ; loss: 0.000
# inference latency =  0.5698549747467041
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 14/20
# 100% 391/391 [00:17<00:00, 22.79it/s, loss=0.231]
# - Train metrics: accuracy: 0.848 ; loss: 0.232
# inference latency =  0.13982796669006348
# - Eval metrics : accuracy: 0.819 ; loss: 0.000
# inference latency =  0.5203087329864502
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 15/20
# 100% 391/391 [00:17<00:00, 22.65it/s, loss=0.229]
# - Train metrics: accuracy: 0.838 ; loss: 0.243
# inference latency =  0.1452181339263916
# - Eval metrics : accuracy: 0.826 ; loss: 0.000
# inference latency =  0.6292703151702881
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 16/20
# 100% 391/391 [00:17<00:00, 22.63it/s, loss=0.223]
# - Train metrics: accuracy: 0.859 ; loss: 0.212
# inference latency =  0.14088964462280273
# - Eval metrics : accuracy: 0.824 ; loss: 0.000
# inference latency =  1.0916168689727783
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 22.38it/s, loss=0.217]
# - Train metrics: accuracy: 0.855 ; loss: 0.214
# inference latency =  0.14054274559020996
# - Eval metrics : accuracy: 0.830 ; loss: 0.000
# inference latency =  0.6100428104400635
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 22.51it/s, loss=0.214]
# - Train metrics: accuracy: 0.857 ; loss: 0.212
# inference latency =  0.14821434020996094
# - Eval metrics : accuracy: 0.837 ; loss: 0.000
# inference latency =  0.5566611289978027
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 19/20
# 100% 391/391 [00:17<00:00, 22.68it/s, loss=0.210]
# - Train metrics: accuracy: 0.875 ; loss: 0.204
# inference latency =  0.1308739185333252
# - Eval metrics : accuracy: 0.836 ; loss: 0.000
# inference latency =  0.5790116786956787
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 22.46it/s, loss=0.208]
# - Train metrics: accuracy: 0.844 ; loss: 0.225
# inference latency =  0.1777477264404297
# - Eval metrics : accuracy: 0.833 ; loss: 0.000
# inference latency =  0.5332560539245605
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  191274

# %% [markdown]
# # 6 Convolutions

# %%
# Combined
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:18<00:00, 21.59it/s, loss=0.626]
# - Train metrics: accuracy: 0.385 ; loss: 0.733
# inference latency =  0.19877409934997559
# - Eval metrics : accuracy: 0.574 ; loss: 0.000
# inference latency =  0.5401613712310791
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 2/20
# 100% 391/391 [00:19<00:00, 20.32it/s, loss=0.430]
# - Train metrics: accuracy: 0.625 ; loss: 0.453
# inference latency =  0.21323895454406738
# - Eval metrics : accuracy: 0.670 ; loss: 0.000
# inference latency =  0.566387414932251
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 3/20
# 100% 391/391 [00:18<00:00, 21.68it/s, loss=0.356]
# - Train metrics: accuracy: 0.738 ; loss: 0.352
# inference latency =  0.21517372131347656
# - Eval metrics : accuracy: 0.728 ; loss: 0.000
# inference latency =  0.5590865612030029
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 21.80it/s, loss=0.315]
# - Train metrics: accuracy: 0.736 ; loss: 0.341
# inference latency =  0.19595909118652344
# - Eval metrics : accuracy: 0.750 ; loss: 0.000
# inference latency =  0.502582311630249
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 21.79it/s, loss=0.290]
# - Train metrics: accuracy: 0.789 ; loss: 0.305
# inference latency =  0.21493840217590332
# - Eval metrics : accuracy: 0.768 ; loss: 0.000
# inference latency =  0.5358583927154541
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 6/20
# 100% 391/391 [00:17<00:00, 21.82it/s, loss=0.270]
# - Train metrics: accuracy: 0.791 ; loss: 0.266
# inference latency =  0.25505518913269043
# - Eval metrics : accuracy: 0.728 ; loss: 0.000
# inference latency =  0.4981808662414551
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 7/20
# 100% 391/391 [00:17<00:00, 21.74it/s, loss=0.251]
# - Train metrics: accuracy: 0.781 ; loss: 0.261
# inference latency =  0.22801613807678223
# - Eval metrics : accuracy: 0.781 ; loss: 0.000
# inference latency =  0.5617387294769287
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 8/20
# 100% 391/391 [00:17<00:00, 21.83it/s, loss=0.240]
# - Train metrics: accuracy: 0.797 ; loss: 0.255
# inference latency =  0.20885586738586426
# - Eval metrics : accuracy: 0.763 ; loss: 0.000
# inference latency =  0.5665736198425293
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 21.83it/s, loss=0.231]
# - Train metrics: accuracy: 0.832 ; loss: 0.235
# inference latency =  0.19820928573608398
# - Eval metrics : accuracy: 0.785 ; loss: 0.000
# inference latency =  0.5930185317993164
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 21.91it/s, loss=0.221]
# - Train metrics: accuracy: 0.820 ; loss: 0.233
# inference latency =  0.22583913803100586
# - Eval metrics : accuracy: 0.806 ; loss: 0.000
# inference latency =  0.5977528095245361
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 21.79it/s, loss=0.212]
# - Train metrics: accuracy: 0.848 ; loss: 0.203
# inference latency =  0.21986794471740723
# - Eval metrics : accuracy: 0.804 ; loss: 0.000
# inference latency =  0.5830492973327637
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 21.90it/s, loss=0.208]
# - Train metrics: accuracy: 0.838 ; loss: 0.212
# inference latency =  0.19063568115234375
# - Eval metrics : accuracy: 0.826 ; loss: 0.000
# inference latency =  0.5630795955657959
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 13/20
# 100% 391/391 [00:17<00:00, 21.75it/s, loss=0.200]
# - Train metrics: accuracy: 0.824 ; loss: 0.213
# inference latency =  0.21492862701416016
# - Eval metrics : accuracy: 0.826 ; loss: 0.000
# inference latency =  0.53194260597229
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 14/20
# 100% 391/391 [00:19<00:00, 20.13it/s, loss=0.194]
# - Train metrics: accuracy: 0.836 ; loss: 0.208
# inference latency =  0.2052464485168457
# - Eval metrics : accuracy: 0.807 ; loss: 0.000
# inference latency =  0.5231709480285645
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 15/20
# 100% 391/391 [00:18<00:00, 21.64it/s, loss=0.190]
# - Train metrics: accuracy: 0.840 ; loss: 0.196
# inference latency =  0.21790051460266113
# - Eval metrics : accuracy: 0.832 ; loss: 0.000
# inference latency =  0.518822193145752
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 16/20
# 100% 391/391 [00:17<00:00, 21.92it/s, loss=0.186]
# - Train metrics: accuracy: 0.865 ; loss: 0.185
# inference latency =  0.22100377082824707
# - Eval metrics : accuracy: 0.815 ; loss: 0.000
# inference latency =  0.6234238147735596
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 21.85it/s, loss=0.181]
# - Train metrics: accuracy: 0.865 ; loss: 0.178
# inference latency =  0.19891738891601562
# - Eval metrics : accuracy: 0.820 ; loss: 0.000
# inference latency =  0.5713927745819092
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 21.90it/s, loss=0.178]
# - Train metrics: accuracy: 0.855 ; loss: 0.191
# inference latency =  0.20151686668395996
# - Eval metrics : accuracy: 0.835 ; loss: 0.000
# inference latency =  0.5254220962524414
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 19/20
# 100% 391/391 [00:17<00:00, 21.82it/s, loss=0.174]
# - Train metrics: accuracy: 0.850 ; loss: 0.180
# inference latency =  0.20794010162353516
# - Eval metrics : accuracy: 0.827 ; loss: 0.000
# inference latency =  0.53326416015625
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 21.84it/s, loss=0.171]
# - Train metrics: accuracy: 0.887 ; loss: 0.159
# inference latency =  0.24422454833984375
# - Eval metrics : accuracy: 0.834 ; loss: 0.000
# inference latency =  0.5490725040435791
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  279882

# %% [markdown]
# # 5 Convolutions

# %%
# Combined
# !python train.py --model_dir experiments/cnn_distill
# Out:
# True
# /////////////////////////
# Loading the datasets...
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# - done.
# Experiment - model version: cnn_distill
# Starting training for 20 epoch(s)
# First, loading the teacher model and computing its outputs...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch 1/20
#   0% 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2887: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% 391/391 [00:17<00:00, 21.76it/s, loss=0.635]
# - Train metrics: accuracy: 0.428 ; loss: 0.720
# inference latency =  0.1460094451904297
# - Eval metrics : accuracy: 0.643 ; loss: 0.000
# inference latency =  0.6606395244598389
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 2/20
# 100% 391/391 [00:19<00:00, 19.92it/s, loss=0.476]
# - Train metrics: accuracy: 0.682 ; loss: 0.470
# inference latency =  0.1768949031829834
# - Eval metrics : accuracy: 0.701 ; loss: 0.000
# inference latency =  0.5741105079650879
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 3/20
# 100% 391/391 [00:18<00:00, 20.86it/s, loss=0.420]
# - Train metrics: accuracy: 0.684 ; loss: 0.432
# inference latency =  0.17776775360107422
# - Eval metrics : accuracy: 0.706 ; loss: 0.000
# inference latency =  0.6070511341094971
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 4/20
# 100% 391/391 [00:17<00:00, 21.84it/s, loss=0.388]
# - Train metrics: accuracy: 0.719 ; loss: 0.408
# inference latency =  0.19791841506958008
# - Eval metrics : accuracy: 0.766 ; loss: 0.000
# inference latency =  0.5334432125091553
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 5/20
# 100% 391/391 [00:17<00:00, 22.08it/s, loss=0.363]
# - Train metrics: accuracy: 0.801 ; loss: 0.349
# inference latency =  0.15408968925476074
# - Eval metrics : accuracy: 0.770 ; loss: 0.000
# inference latency =  0.5748121738433838
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 6/20
# 100% 391/391 [00:17<00:00, 22.28it/s, loss=0.344]
# - Train metrics: accuracy: 0.795 ; loss: 0.311
# inference latency =  0.16179418563842773
# - Eval metrics : accuracy: 0.787 ; loss: 0.000
# inference latency =  0.6261472702026367
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 7/20
# 100% 391/391 [00:17<00:00, 22.49it/s, loss=0.328]
# - Train metrics: accuracy: 0.787 ; loss: 0.324
# inference latency =  0.18898582458496094
# - Eval metrics : accuracy: 0.784 ; loss: 0.000
# inference latency =  0.5910701751708984
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 8/20
# 100% 391/391 [00:17<00:00, 22.02it/s, loss=0.319]
# - Train metrics: accuracy: 0.760 ; loss: 0.339
# inference latency =  0.16976118087768555
# - Eval metrics : accuracy: 0.797 ; loss: 0.000
# inference latency =  0.5652420520782471
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 9/20
# 100% 391/391 [00:17<00:00, 22.17it/s, loss=0.307]
# - Train metrics: accuracy: 0.812 ; loss: 0.295
# inference latency =  0.16771912574768066
# - Eval metrics : accuracy: 0.800 ; loss: 0.000
# inference latency =  0.5965993404388428
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 10/20
# 100% 391/391 [00:17<00:00, 22.35it/s, loss=0.301]
# - Train metrics: accuracy: 0.814 ; loss: 0.303
# inference latency =  0.1661529541015625
# - Eval metrics : accuracy: 0.801 ; loss: 0.000
# inference latency =  0.551220178604126
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 11/20
# 100% 391/391 [00:17<00:00, 22.35it/s, loss=0.292]
# - Train metrics: accuracy: 0.812 ; loss: 0.293
# inference latency =  0.17842817306518555
# - Eval metrics : accuracy: 0.808 ; loss: 0.000
# inference latency =  0.5964715480804443
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 12/20
# 100% 391/391 [00:17<00:00, 22.33it/s, loss=0.287]
# - Train metrics: accuracy: 0.807 ; loss: 0.282
# inference latency =  0.14934611320495605
# - Eval metrics : accuracy: 0.820 ; loss: 0.000
# inference latency =  0.5314130783081055
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 13/20
# 100% 391/391 [00:17<00:00, 22.51it/s, loss=0.280]
# - Train metrics: accuracy: 0.824 ; loss: 0.274
# inference latency =  0.16171932220458984
# - Eval metrics : accuracy: 0.829 ; loss: 0.000
# inference latency =  0.5662951469421387
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 14/20
# 100% 391/391 [00:17<00:00, 22.48it/s, loss=0.276]
# - Train metrics: accuracy: 0.812 ; loss: 0.271
# inference latency =  0.1643357276916504
# - Eval metrics : accuracy: 0.814 ; loss: 0.000
# inference latency =  0.5650017261505127
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 15/20
# 100% 391/391 [00:17<00:00, 22.54it/s, loss=0.270]
# - Train metrics: accuracy: 0.852 ; loss: 0.257
# inference latency =  0.18412232398986816
# - Eval metrics : accuracy: 0.825 ; loss: 0.000
# inference latency =  0.5836505889892578
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 16/20
# 100% 391/391 [00:18<00:00, 20.67it/s, loss=0.268]
# - Train metrics: accuracy: 0.852 ; loss: 0.248
# inference latency =  0.17097949981689453
# - Eval metrics : accuracy: 0.833 ; loss: 0.000
# inference latency =  0.5587916374206543
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 17/20
# 100% 391/391 [00:17<00:00, 22.50it/s, loss=0.262]
# - Train metrics: accuracy: 0.850 ; loss: 0.241
# inference latency =  0.18822526931762695
# - Eval metrics : accuracy: 0.840 ; loss: 0.000
# inference latency =  0.5769016742706299
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 18/20
# 100% 391/391 [00:17<00:00, 22.38it/s, loss=0.259]
# - Train metrics: accuracy: 0.838 ; loss: 0.270
# inference latency =  0.1903524398803711
# - Eval metrics : accuracy: 0.838 ; loss: 0.000
# inference latency =  0.6400084495544434
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 19/20
# 100% 391/391 [00:17<00:00, 22.07it/s, loss=0.256]
# - Train metrics: accuracy: 0.850 ; loss: 0.241
# inference latency =  0.1635429859161377
# - Eval metrics : accuracy: 0.841 ; loss: 0.000
# inference latency =  0.5859417915344238
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
# Epoch 20/20
# 100% 391/391 [00:17<00:00, 22.30it/s, loss=0.252]
# - Train metrics: accuracy: 0.820 ; loss: 0.259
# inference latency =  0.19557404518127441
# - Eval metrics : accuracy: 0.838 ; loss: 0.000
# inference latency =  0.6035287380218506
# - Eval metrics : accuracy: 0.942 ; loss: 0.000
# Checkpoint Directory exists!
# - Found new best accuracy
# Number of parameters  253354
